# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from utility import get_data
from sklearn.model_selection import train_test_split

# Load data
df = get_data()
X_train, X_test, y_train, y_test = train_test_split(df.drop(columns=['StudentID', 'Semester', 'MDM', 'Stat', 'Formalise', 'Cost', 'Final_Exam_Score']), df['Final_Exam_Score'], test_size=0.3, random_state=42)
# Out:
# Loading and cleaning quiz data for SemesterX...
# Loading and cleaning exam data for SemesterX...
# Merging quiz and exam data for SemesterX...
# Loading and cleaning quiz data for SemesterY...
# Loading and cleaning exam data for SemesterY...
# Merging quiz and exam data for SemesterY...

# %%
# ==========================================
# 1. Linear Regression Model
# ==========================================
X_train_filled = X_train.fillna(0)
X_test_filled = X_test.fillna(0)
lr_model = LinearRegression()
lr_model.fit(X_train_filled, y_train)

# Predict and evaluate
lr_preds = lr_model.predict(X_test_filled)
print("--- Linear Regression ---")
print(f"MSE: {mean_squared_error(y_test, lr_preds):.4f}")
print(f"R2 Score: {r2_score(y_test, lr_preds):.4f}\n")
# Out:
# --- Linear Regression ---
# MSE: 0.4669
# R2 Score: -10.0852
# C:\Users\denis\AppData\Local\Temp\ipykernel_43340\853323537.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X_train_filled = X_train.fillna(0)
# C:\Users\denis\AppData\Local\Temp\ipykernel_43340\853323537.py:5: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X_test_filled = X_test.fillna(0)

# %%
# ==========================================
# 2. Random Forest Model
# ==========================================
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict and evaluate
rf_preds = rf_model.predict(X_test)
print("--- Random Forest ---")
print(f"MSE: {mean_squared_error(y_test, rf_preds):.4f}")
print(f"R2 Score: {r2_score(y_test, rf_preds):.4f}")
# Out:
# --- Random Forest ---
# MSE: 0.0447
# R2 Score: -0.0609
