# %%
from utility import get_data

df = get_data()
# Out:
# Loading and cleaning quiz data for SemesterY...
# Loading and cleaning exam data for SemesterY...
# Merging quiz and exam data for SemesterY...
# Loading and cleaning quiz data for SemesterX...
# Loading and cleaning exam data for SemesterX...
# Merging quiz and exam data for SemesterX...

# %%
df['StudentID'].nunique()
# Out:
# 133

# %%
df
# Out:
#                                              StudentID  statistics_Attempts  \
# 0    5210ef9c322b829d6f89524264889cd03d8b00d313d54e...                  2.0
# 1    fabb27f5dcfc053e6c070258816edaf94c7f2963c81343...                  1.0
# 2    0364dd853e3d05dd749ae2a991c62129e91a60615aaa61...                  3.0
# 3    7ceed9e99b7f397df60cba5d022995fe4828833500fb4c...                  1.0
# 4    861b44582cd8978120a8f12addb6de1d2d1c8986a724e9...                  2.0
# ..                                                 ...                  ...
# 130  b9ae79f83725cca1de23d3a598c22f7dba4e745bc974f5...                  0.0
# 131  82b255dbc16e2b9f617c630f399f662c856d6702d4116e...                  3.0
# 132  b358f6318ba8138cf5ea47c7f2cdaa1fdfa297a3654186...                  2.0
# 133  37c56263b0e146d2d155fe3c5cc585f19deaa3125a6edd...                  2.0
# 134  2f1543846313a3bc97a249580c34eaa5e94fdc0ef2ea4b...                  1.0
#
# ...
