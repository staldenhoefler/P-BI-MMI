# %%
from utility import get_data

df = get_data()
# Out:
# Loading and cleaning quiz data for SemesterX...
# Loading and cleaning exam data for SemesterX...
# Merging quiz and exam data for SemesterX...
# Loading and cleaning quiz data for SemesterY...
# Loading and cleaning exam data for SemesterY...
# Merging quiz and exam data for SemesterY...

# %%
df['StudentID'].nunique()
# Out:
# 133

# %%
df
# Out:
#                                              StudentID  statistics_Attempts  \
# 0    ac099562b4dd4e613d4d69c8a6fdd2cce55395eb5bc714...                  1.0
# 1    3035339c73756001d90acea7dd2b78269a9b05504dc946...                  2.0
# 2    b6592318954a0c86f1228fc71d0ba7ca474d9f4722825b...                  3.0
# 3    d38a4c8209292f74c2ac234e61a9e45ed60f46611593d0...                  1.0
# 4    3f8907f83cb1986884385be44ec0bc6b0751207952f48a...                  1.0
# ..                                                 ...                  ...
# 130  5de86005bd42f26bcec592ca8f00c954b09423d789ed68...                  1.0
# 131  770037dbdc4875e2e3d9be0eddf271f1b115a76ab6c9e4...                  1.0
# 132  c95c582b0ea33b7b429328ee32a6f079af77cdcf5c6816...                  1.0
# 133  99481d4159ab45b21c6fb431486fa77471f4b55330c21b...                  2.0
# 134  94e94f2cb0b7cab080a0d2ecc7083ce83fb09d4314ba67...                  0.0
#
#     statistics_Score/10.00_mean statistics_Score/10.00_max  \
# 0                          8.27                       8.27
# 1                         7.545                       9.62
# 2                          7.08                       10.0
# 3                          7.88                       7.88
# 4                          7.41                       7.41
# ..                          ...                        ...
# 130                        7.19                       7.19
# 131                        7.93                       7.93
# 132                        7.24                       7.24
# 133                        8.26                       10.0
# 134                         NaN                        NaN
#
#     statistics_Score/10.00_min  statistics_Duration_minutes_sum  \
# 0                         8.27                       240.000000
# 1                         5.47                        61.833333
# 2                         3.75                      2790.000000
# 3                         7.88                        47.800000
# 4                         7.41                        13.000000
# ..                         ...                              ...
# 130                       7.19                        37.033333
# 131                       7.93                        44.850000
# 132                       7.24                       240.000000
# 133                       6.52                       311.683333
# 134                        NaN                         0.000000
#
#      statistics_Duration_minutes_mean statistics_F 1_mean statistics_F 1_max  \
# 0                          240.000000                 1.0                1.0
# 1                           30.916667            0.833333                1.0
# 2                          930.000000                 1.0                1.0
# 3                           47.800000                 1.0                1.0
# 4                           13.000000                 1.0                1.0
# ..                                ...                 ...                ...
# 130                         37.033333                 1.0                1.0
# 131                         44.850000                 1.0                1.0
# 132                        240.000000                 1.0                1.0
# 133                        155.841667            0.746032                1.0
# 134                          0.000000                 NaN                NaN
#
#     statistics_F 1_min  ... regression_F 12_min regression_F 13_mean  \
# 0                  1.0  ...                 NaN                  NaN
# 1             0.666667  ...                 1.0                  1.0
# 2                  1.0  ...                 0.0             0.660714
# 3                  1.0  ...                 NaN                  NaN
# 4                  1.0  ...                 1.0             0.678571
# ..                 ...  ...                 ...                  ...
# 130                1.0  ...                 1.0                  1.0
# 131                1.0  ...                 NaN                  NaN
# 132                1.0  ...                 NaN                  NaN
# 133           0.492063  ...                 NaN                  NaN
# 134                NaN  ...                 NaN                  NaN
#
#     regression_F 13_max regression_F 13_min   MDM  Stat Formalise  Cost  \
# 0                   NaN                 NaN  0.83  0.95      0.94  0.83
# 1                   1.0                 1.0  0.87  0.90      0.50  0.67
# 2                   1.0            0.321429  0.60  0.25      0.38  0.22
# 3                   NaN                 NaN  0.77  0.65      0.69  0.78
# 4              0.678571            0.678571  0.70  0.80      0.44  0.89
# ..                  ...                 ...   ...   ...       ...   ...
# 130                 1.0                 1.0  0.87  0.88      0.88  0.38
# 131                 NaN                 NaN  0.77  0.44      0.81  0.94
# 132                 NaN                 NaN  0.70  0.44      0.50  0.06
# 133                 NaN                 NaN  0.27  0.19      0.13  0.75
# 134                 NaN                 NaN  0.67  0.94      0.75  0.38
#
#       Semester Final_Exam_Score
# 0    SemesterX           0.8875
# 1    SemesterX           0.7350
# 2    SemesterX           0.3625
# 3    SemesterX           0.7225
# 4    SemesterX           0.7075
# ..         ...              ...
# 130  SemesterY           0.7525
# 131  SemesterY           0.7400
# 132  SemesterY           0.4250
# 133  SemesterY           0.3350
# 134  SemesterY           0.6850
#
# [135 rows x 229 columns]

# %%
output_filename = 'data/Processed_Data.csv'
df.to_csv(output_filename, index=False)
print(f"Merged DataFrame exported to {output_filename}")
# Out:
# Merged DataFrame exported to data/Processed_Data.csv
